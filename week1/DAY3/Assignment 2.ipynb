-- %%
CREATE TABLE CustomerUsage (
customer_id INT PRIMARY KEY,
customer_name VARCHAR(50),
plan_type VARCHAR(20),
data_used_gb INT,
call_minutes INT,
monthly_bill DECIMAL(10,2)
);
INSERT INTO CustomerUsage VALUES
(1, 'Veena', 'Postpaid', 9, 471, 842.03),
(2, 'Veer', 'Postpaid', 7, 354, 434.94),
(3, 'Mohan', 'Prepaid', 33, 497, 569.23),
(4, 'Pratik', 'Prepaid', 15, 113, 1107.48),
(5, 'Farhan', 'Prepaid', 14, 1284, 845.75),
(6, 'Jiya', 'Postpaid', 28, 1578, 1325.15);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>6</td><td>6</td></tr></tbody></table></div>

-- %%
---1
SELECT *,
CASE 
    WHEN plan_type = 'Prepaid' AND (monthly_bill > 400 OR call_minutes > 550) 
        THEN 'Suggest Postpaid Upgrade'
    WHEN plan_type = 'Prepaid' 
        THEN 'No Upgrade'
    WHEN plan_type = 'Postpaid' AND data_used_gb > 25 
        THEN 'Suggest Premium Plan'
    ELSE 'Satisfactory Usage'
END AS plan_upgrade
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>plan_upgrade</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Satisfactory Usage</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Satisfactory Usage</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Suggest Postpaid Upgrade</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Suggest Postpaid Upgrade</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Suggest Postpaid Upgrade</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Suggest Premium Plan</td></tr></tbody></table></div>

-- %%
---2
SELECT *,
CASE 
    WHEN plan_type = 'Postpaid' AND data_used_gb >= 30 
        THEN 'Heavy User - Postpaid'
    WHEN plan_type = 'Postpaid' AND data_used_gb BETWEEN 15 AND 29 
        THEN 'Moderate User - Postpaid'
    WHEN plan_type = 'Postpaid' 
        THEN 'Light User - Postpaid'
    WHEN plan_type = 'Prepaid' AND data_used_gb >= 20 
        THEN 'Heavy User - Prepaid'
    ELSE 'Light User - Prepaid'
END AS usage_category
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>usage_category</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Light User - Postpaid</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Light User - Postpaid</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Heavy User - Prepaid</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Light User - Prepaid</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Light User - Prepaid</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Moderate User - Postpaid</td></tr></tbody></table></div>

-- %%
---3
SELECT *,
CASE 
    WHEN call_minutes > 1200 AND monthly_bill > 1000 
        THEN 'Excessive Talker - Premium'
    WHEN call_minutes > 1200 
        THEN 'Excessive Talker - Standard'
    WHEN call_minutes BETWEEN 800 AND 1200 
        THEN 'Frequent Caller'
    ELSE 'Normal Caller'
END AS voice_usage
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>voice_usage</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Normal Caller</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Normal Caller</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Normal Caller</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Normal Caller</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Excessive Talker - Standard</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Excessive Talker - Premium</td></tr></tbody></table></div>

-- %%
---4
SELECT *,
CASE 
    WHEN plan_type = 'Postpaid' AND data_used_gb > 25 AND call_minutes > 1000 
        THEN 'Combo Offer'
    WHEN plan_type = 'Prepaid' AND monthly_bill > 600 
        THEN 'Recharge Cashback Offer'
    ELSE 'No Offer'
END AS offer_status
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>offer_status</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>No Offer</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>No Offer</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>No Offer</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Recharge Cashback Offer</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Recharge Cashback Offer</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Combo Offer</td></tr></tbody></table></div>

-- %%
---5
SELECT *,
CASE 
    WHEN data_used_gb > 25 AND call_minutes > 1000 
        THEN 'Gold Tier'
    WHEN data_used_gb > 25 
        THEN 'Silver Tier'
    WHEN call_minutes > 800 
        THEN 'Bronze Tier'
    ELSE 'Basic Tier'
END AS reward_tier
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>reward_tier</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Basic Tier</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Basic Tier</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Silver Tier</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Basic Tier</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Bronze Tier</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Gold Tier</td></tr></tbody></table></div>

-- %%
---6
SELECT *,
CASE 
    WHEN plan_type = 'Postpaid' AND monthly_bill < 500 
        THEN 'Underutilized Postpaid'
    WHEN plan_type = 'Prepaid' AND monthly_bill > 900 
        THEN 'Overpaying Prepaid'
    ELSE 'Plan Matches Usage'
END AS mismatch_status
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>mismatch_status</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Plan Matches Usage</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Underutilized Postpaid</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Plan Matches Usage</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Overpaying Prepaid</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Plan Matches Usage</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Plan Matches Usage</td></tr></tbody></table></div>

-- %%
---7
SELECT *,
CASE 
    WHEN data_used_gb > 25 AND call_minutes > 1000 AND monthly_bill > 1200 
        THEN 'Super User'
    WHEN data_used_gb > 25 AND call_minutes > 1000 
        THEN 'High Usage Customer'
    ELSE 'Standard User'
END AS user_type
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>user_type</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Standard User</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Standard User</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Standard User</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Standard User</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Standard User</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Super User</td></tr></tbody></table></div>

-- %%
---8
SELECT *,
CASE 
    WHEN call_minutes > data_used_gb * 30 
        THEN 'Voice Oriented User'
    WHEN data_used_gb > call_minutes / 30 
        THEN 'Data Oriented User'
    ELSE 'Balanced Usage'
END AS preference
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>preference</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Voice Oriented User</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Voice Oriented User</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Data Oriented User</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Data Oriented User</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Voice Oriented User</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Voice Oriented User</td></tr></tbody></table></div>

-- %%
---9
SELECT *,
CASE 
    WHEN monthly_bill > 1000 AND plan_type = 'Prepaid' 
        THEN 'Offer Switch + Discount'
    WHEN monthly_bill > 1000 AND plan_type = 'Postpaid' 
        THEN 'Offer Loyalty Discount'
    ELSE 'No Discount'
END AS discount_status
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>discount_status</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>No Discount</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>No Discount</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>No Discount</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Offer Switch + Discount</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>No Discount</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Offer Loyalty Discount</td></tr></tbody></table></div>

-- %%
---10
SELECT *,
CASE 
    WHEN data_used_gb > 25 AND monthly_bill < 700 
        THEN 'High Efficiency User'
    WHEN data_used_gb > 25 
        THEN 'Premium Digital User'
    ELSE 'Standard Engagement'
END AS engagement_tag
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>engagement_tag</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Standard Engagement</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Standard Engagement</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>High Efficiency User</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Standard Engagement</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Standard Engagement</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Premium Digital User</td></tr></tbody></table></div>

-- %%
---11
SELECT *,
CASE 
    WHEN call_minutes > 1500 AND data_used_gb < 10 
        THEN 'Heavy Voice, Low Data'
    WHEN data_used_gb > 25 AND call_minutes < 500 
        THEN 'Heavy Data, Light Talk'
    ELSE 'Balanced or Low Usage'
END AS usage_pattern
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>usage_pattern</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Balanced or Low Usage</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Balanced or Low Usage</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Heavy Data, Light Talk</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Balanced or Low Usage</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Balanced or Low Usage</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Balanced or Low Usage</td></tr></tbody></table></div>

-- %%
---12
SELECT *,
CASE 
    WHEN plan_type = 'Postpaid' AND monthly_bill > 800 AND call_minutes > 1200 
        THEN 'Elite Postpaid User'
    WHEN plan_type = 'Postpaid' AND monthly_bill > 800 
        THEN 'Premium Postpaid User'
    WHEN plan_type = 'Prepaid' 
        THEN 'Prepaid User'
END AS user_tag
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>user_tag</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Premium Postpaid User</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>null</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Prepaid User</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Prepaid User</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Prepaid User</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Elite Postpaid User</td></tr></tbody></table></div>

-- %%
---13
SELECT *,
CASE 
    WHEN data_used_gb > 20 AND monthly_bill BETWEEN 800 AND 1000 
        THEN 'Gold Data Pack Suggested'
    WHEN data_used_gb > 30 
        THEN 'Platinum Data Pack Suggested'
    ELSE 'Standard Plan'
END AS data_plan
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>data_plan</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Standard Plan</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Standard Plan</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Platinum Data Pack Suggested</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Standard Plan</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Standard Plan</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Standard Plan</td></tr></tbody></table></div>

-- %%
---14
SELECT *,
CASE 
    WHEN call_minutes > 1000 AND monthly_bill < 700 
        THEN 'Value Talker'
    WHEN call_minutes > 1000 
        THEN 'Premium Talker'
    ELSE 'Normal Caller'
END AS talker_type
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>talker_type</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Normal Caller</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Normal Caller</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Normal Caller</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Normal Caller</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Premium Talker</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Premium Talker</td></tr></tbody></table></div>

-- %%
---15
SELECT *,
CASE 
    WHEN plan_type = 'Prepaid' AND data_used_gb > 25 
        THEN 'Prepaid Power User'
    WHEN plan_type = 'Postpaid' AND data_used_gb > 25 
        THEN 'Postpaid Power User'
    ELSE 'Normal User'
END AS power_user_status
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>power_user_status</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Normal User</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Normal User</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Prepaid Power User</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Normal User</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Normal User</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Postpaid Power User</td></tr></tbody></table></div>
